# %%
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
import pandas as pd

# %%
dataset = pd.read_csv("https://archive.ics.uci.edu/ml/machine-learning-databases/iris/iris.data",
names =["sepal length","sepal width","petal length","petal width","class"])

# %%
dataset.head()
# Out:
#    sepal length  sepal width  petal length  petal width        class
# 0           5.1          3.5           1.4          0.2  Iris-setosa
# 1           4.9          3.0           1.4          0.2  Iris-setosa
# 2           4.7          3.2           1.3          0.2  Iris-setosa
# 3           4.6          3.1           1.5          0.2  Iris-setosa
# 4           5.0          3.6           1.4          0.2  Iris-setosa

# %%
# %matplotlib inline
img=mpimg.imread('iris_types.jfif')
plt.figure(figsize=(20,40))
plt.axis('off')
plt.imshow(img)

# %%
X = dataset.iloc[:,:4].values
y = dataset['sepal length'].values

# %%
from sklearn.model_selection
import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.20, random_st1
# Out:
#   File "C:\Users\D_COMP~1\AppData\Local\Temp/ipykernel_9528/667867530.py", line 1
#     from sklearn.model_selection
#                                 ^
# SyntaxError: invalid syntax

# %%
from sklearn.preprocessing import StandardScaler
sc = StandardScaler()
X_train = sc.fit_transform(X_train)
X_test = sc.transform(X_test)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# C:\Users\D_COMP~1\AppData\Local\Temp/ipykernel_9528/2609638334.py in <module>
#       1 from sklearn.preprocessing import StandardScaler
#       2 sc = StandardScaler()
# ----> 3 X_train = sc.fit_transform(X_train)
#       4 X_test = sc.transform(X_test)
#
# NameError: name 'X_train' is not defined

# %%
from sklearn.naive_bayes import GaussianNB
nvclassifier = GaussianNB()
nvclassifier.fit(X_train, y_train)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# C:\Users\D_COMP~1\AppData\Local\Temp/ipykernel_9528/4186067895.py in <module>
#       1 from sklearn.naive_bayes import GaussianNB
#       2 nvclassifier = GaussianNB()
# ----> 3 nvclassifier.fit(X_train, y_train)
#
# NameError: name 'X_train' is not defined

# %%
y_pred = nvclassifier.predict(X_test)
print(y_pred)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# C:\Users\D_COMP~1\AppData\Local\Temp/ipykernel_9528/1558529778.py in <module>
# ----> 1 y_pred = nvclassifier.predict(X_test)
#       2 print(y_pred)
#
# NameError: name 'X_test' is not defined
